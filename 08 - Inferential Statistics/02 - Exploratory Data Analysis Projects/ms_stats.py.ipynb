# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import ms_stats as mss

# %%
mss.permutation_sample([1,2,3],[4,5,6])
# Out:
# (array([1, 6, 2]), array([4, 5, 3]))

# %%
x,y = mss.ecdf(mss.np.random.poisson(5,1000000))

# %%
plt.plot(x,y,linestyle='none',marker='.')

# %%
x1,y1 = mss.ecdf(mss.np.random.normal(5,1,1000))
x2,y2 = mss.ecdf(mss.np.random.normal(5,2,1000))

# %%
plt.subplots(1,1,figsize=(12,6))
for std in range(1,6):
    x,y =  mss.ecdf(mss.np.random.normal(0,std,1000))
    plt.plot(x,y,linestyle='none',marker='o', alpha=0.2,label=str(std))
    #plt.xlim(-10,10)
    plt.legend()

# %%
plt.subplots(1,1,figsize=(12,6))
for mean in range(1,21):
    x,y =  mss.ecdf(mss.np.random.poisson(mean,1000))
    plt.plot(x,y,linestyle='none',marker='o', alpha=0.2,label=str(std))
    #plt.xlim(-10,10)
    plt.legend()

# %%
plt.subplots(1,1,figsize=(12,6))
for trials in range(1,21):
    prob_success = 0.25
    x,y =  mss.ecdf(mss.np.random.binomial(trials,prob_success,1000))
    plt.plot(x,y,linestyle='none',marker='o', alpha=0.2,label=str(std))
    #plt.xlim(-10,10)
    plt.legend()

# %%
# ?mss.np.random.binomial

# %%
mss.np.random.binomial(9, 0.1, 20000)
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %% [markdown]
# ## Pipeline for hypothesis testing
# 1. Clearly state the **null hypothesis**
# 2. **Define** your **test statistic**
# 3. **Generate** many sets of simulated **data** assuming the null hypothesis is true
# 4. **Compute** the **test statistic** for each simulated data set
# 5. The **p-value** is the fraction of your simulated data sets for wich the test statistic is at least as extreme as for the real data
