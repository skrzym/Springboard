# %%
import nflgame

# %%
dir(nflgame)
# Out:
# ['NoPlayers',
#  'OrderedDict',
#  'VERSION',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__version__',
#  '_search_schedule',
#  'combine',
#  'combine_game_stats',
#  'combine_max_stats',
#  'combine_play_stats',
#  'combine_plays',
#  'find',
#  'game',
#  'games',
#  'games_gen',
#  'itertools',
#  'live',
#  'nflgame',
#  'one',
#  'player',
#  'players',
#  'sched',
#  'seq',
#  'standard_team',
#  'statmap',
#  'sys',
#  'teams',
#  'update_sched',
#  'version']

# %%
rs15 = nflgame.games(2015)

# %%
for game in rs15:
    print(game.nice_score())
# Out:
# PIT (21) at NE (28)
# GB (31) at CHI (23)
# SEA (31) at STL (34)
# CAR (20) at JAC (9)
# MIA (17) at WAS (10)
# IND (14) at BUF (27)
# CLE (10) at NYJ (31)
# KC (27) at HOU (20)
# NO (19) at ARI (31)
# DET (28) at SD (33)
# BAL (13) at DEN (19)
# CIN (33) at OAK (13)
# TEN (42) at TB (14)
# NYG (26) at DAL (27)
# PHI (24) at ATL (26)
# MIN (3) at SF (20)
# DEN (31) at KC (24)
# HOU (17) at CAR (24)
# NE (40) at BUF (32)
# SD (19) at CIN (24)
# TEN (14) at CLE (28)
# ATL (24) at NYG (20)
# STL (10) at WAS (24)
# ARI (48) at CHI (23)
# DET (16) at MIN (26)
# TB (26) at NO (19)
# SF (18) at PIT (43)
# BAL (33) at OAK (37)
# MIA (20) at JAC (23)
# DAL (20) at PHI (10)
# SEA (17) at GB (27)
# NYJ (20) at IND (7)
# WAS (21) at NYG (32)
# ATL (39) at DAL (28)
# NO (22) at CAR (27)
# PHI (24) at NYJ (17)
# TB (9) at HOU (19)
# SD (14) at MIN (31)
# PIT (12) at STL (6)
# JAC (17) at NE (51)
# CIN (28) at BAL (24)
# OAK (27) at CLE (20)
# IND (35) at TEN (33)
# SF (7) at ARI (47)
# ...

# %%
nflgame.game.Game.max_player_stats

# %%
rs15[0].max_player_stats()

# %%
rsp15 = nflgame.combine_plays(rs15)
for p in rsp15.sort('passing_yds').limit(5):
    print p
# Out:
# (JAC, JAC 10, Q3, 1 and 20) (5:00) (Shotgun) B.Bortles pass deep left to A.Robinson for 90 yards, TOUCHDOWN.
# (PIT, PIT 12, Q4, 2 and 8) (2:15) (Shotgun) L.Jones pass short middle to M.Bryant for 88 yards, TOUCHDOWN [C.Campbell]. PENALTY on ARI-C.Campbell, Roughing the Passer, 15 yards, enforced between downs.
# (IND, IND 13, Q3, 2 and 10) (3:56) (Shotgun) A.Luck pass deep left to T.Hilton for 87 yards, TOUCHDOWN.
# (CHI, CHI 13, Q1, 2 and 11) (11:24) (Shotgun) J.Cutler pass short left to Z.Miller for 87 yards, TOUCHDOWN.
# (NYG, NYG 13, Q1, 2 and 6) (6:03) (No Huddle, Shotgun) E.Manning pass deep right to O.Beckham Jr. for 87 yards, TOUCHDOWN.

# %%
help(nflgame.game)
# Out:
# Help on module nflgame.game in nflgame:
#
# NAME
#     nflgame.game
#
# FILE
#     c:\users\skrzym\anaconda3\envs\python27\lib\site-packages\nflgame\game.py
#
# CLASSES
#     __builtin__.object
#         Drive
#         FieldPosition
#         Game
#         GameClock
#         Play
#         PossessionTime
#     __builtin__.tuple(__builtin__.object)
#         GameDiff
#         TeamStats
#
#     class Drive(__builtin__.object)
#      |  Drive represents a single drive in an NFL game. It contains a list
#      |  of all plays that happened in the drive, in chronological order.
#      |  It also contains meta information about the drive such as the start
#      |  and stop times and field position, length of possession, the number
#      |  of first downs and a short descriptive string of the result of the
#      |  drive.
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, other)
#      |      Adds the statistics of two drives together.
#      |
# ...
